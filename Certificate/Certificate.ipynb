# %%
from hashlib import sha1

def compute_hash(email):
    return sha1(email.encode('utf-8')).hexdigest()

def compute_certificate_id(email):
    email_clean = email.lower().strip()
    return compute_hash(email_clean + '_')

# %%
cohort = 2025
course = 'ml-zoomcamp'
your_id = compute_certificate_id('aliaksandra.babova@gmail.com')
url = f"https://certificate.datatalks.club/{course}/{cohort}/{your_id}.pdf"
print(url)
# Out:
# https://certificate.datatalks.club/ml-zoomcamp/2025/78512213e852fac82ab006c37d752ac45e2f5404.pdf
